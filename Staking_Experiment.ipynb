# %%
from google.colab import files
uploaded = files.upload()  # zip 파일 업로드 (pattern_recognition.zip)
# Out:
#      <input type="file" id="files-4375f0b3-7619-4d86-9b36-3e40ff0c467f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4375f0b3-7619-4d86-9b36-3e40ff0c467f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

# zip 압축 해제
with zipfile.ZipFile("pattern_recognition.zip", 'r') as zip_ref:
    zip_ref.extractall("pattern_recognition")

# 작업 디렉토리 이동
os.chdir("pattern_recognition/scripts")

# %%
# !pip install lightgbm scikit-learn

# %%
# !python3 final_stacking_experiment.py
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 8691, number of negative: 8829
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015073 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7189
# [LightGBM] [Info] Number of data points in the train set: 17520, number of used features: 53
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.496062 -> initscore=-0.015754
# [LightGBM] [Info] Start training from score -0.015754
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 6953, number of negative: 7063
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021880 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7165
# ...

# %%
# 파일 복사 (상위 디렉토리에서 현재 작업 디렉토리로)
# !cp ../prediction_stacking.csv .
# !cp ../stacking_model.pkl .

# Colab에서 파일 다운로드
from google.colab import files
files.download('prediction_stacking.csv')
files.download('stacking_model.pkl')
